# %% [markdown]
# # Proyek Analisis Data: [Bike-sharing-dataset]
# - **Nama:** [Owen Orlando]
# - **Email:** [m197b4ky3465@bangkit.academy]
# - **ID Dicoding:** [owen_orlando_m197b4ky3465_sZVQ]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apakah penggunaan sepeda ditentukan oleh musim dan kondisi cuaca?
# - Apakah terdapat perbedaan saat penggunaan sepeda antara weekday (hari kerja) dan weekend (hari libur)?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv('sample_data/day.csv')
print("Preview Data:")
display(df.head())
# Out:
# Preview Data:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:**
# - Data terdiri dari 731 baris dengan 16 kolom
# - Terdapat kolom season, weathersit, holiday, dan working day yang merupakan data bentuk kategori

# %% [markdown]
# ### Assessing Data

# %%
print("\nInformasi Dataset:")
df.info()

print("\nStatistik Deskriptif Dataset:")
display(df.describe())
print("\nCek Missing Values:")
print(df.isnull().sum())
print("\nCek Duplikasi:")
print(df.duplicated().sum())

print("\nUnique Values untuk Kolom Kategori:")
print("Season:", df['season'].unique())
print("Weathersit:", df['weathersit'].unique())
print("Holiday:", df['holiday'].unique())
print("Workingday:", df['workingday'].unique())
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
#
# Statistik Deskriptif Dataset:
# ...

# %% [markdown]
# **Insight:**
# - Tidak ditemukan adanya missing values ataupun duplikasi dalam dataset
# - Kolom kategori memiliki nilai yang sesuai dengan deskripsi seperti season (1(spring), 2(summer), 3(fall), dan 4 winter) dan weathersit.

# %% [markdown]
# ### Cleaning Data

# %%
df['season'] = df['season'].map({1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})
df['weathersit'] = df['weathersit'].map({
    1: 'Clear',
    2: 'Mist',
    3: 'Light Rain/Snow',
    4: 'Heavy Rain/Snow'
})
df['workingday'] = df['workingday'].map({1: 'Weekday', 0: 'Weekend'})
df['holiday'] = df['holiday'].map({1: 'Holiday', 0: 'Not Holiday'})

print("Preview Data Setelah Pembersihan:")
display(df.head())
# Out:
# Preview Data Setelah Pembersihan:
#    instant      dteday  season  yr  mnth      holiday  weekday workingday  \
# 0        1  2011-01-01  Spring   0     1  Not Holiday        6    Weekend
# 1        2  2011-01-02  Spring   0     1  Not Holiday        0    Weekend
# 2        3  2011-01-03  Spring   0     1  Not Holiday        1    Weekday
# 3        4  2011-01-04  Spring   0     1  Not Holiday        2    Weekday
# 4        5  2011-01-05  Spring   0     1  Not Holiday        3    Weekday
#
#   weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0       Mist  0.344167  0.363625  0.805833   0.160446     331         654
# 1       Mist  0.363478  0.353739  0.696087   0.248539     131         670
# 2      Clear  0.196364  0.189405  0.437273   0.248309     120        1229
# 3      Clear  0.200000  0.212122  0.590435   0.160296     108        1454
# 4      Clear  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# ...

# %% [markdown]
# **Insight:**
# - Kolom kategori sudah dikonversi menjadi deskripsi sehingga lebih mudah untuk dipahami
# - Data sudah siap untuk ke tahap exploratory data analysis (EDA)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='season', y='cnt', data=df, estimator=sum, palette='viridis')
plt.title("Penggunaan Sepeda Berdasarkan Musim")
plt.show()

plt.figure(figsize=(8, 5))
sns.barplot(x='weathersit', y='cnt', data=df, estimator=sum, palette='coolwarm')
plt.title("Penggunaan Sepeda Berdasarkan Kondisi Cuaca")
plt.show()
# Out:
# <ipython-input-15-dd107ea2f41b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='season', y='cnt', data=df, estimator=sum, palette='viridis')
# <ipython-input-15-dd107ea2f41b>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weathersit', y='cnt', data=df, estimator=sum, palette='coolwarm')

# %% [markdown]
# **Insight:**
# - Penggunaan sepeda lebih tinggi pada weekday (hari kerja)
# - pada hari libur (weekend), penggunaan sepeda cenderung lebih rendah

# %% [markdown]
# ### Pertanyaan 2:

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='workingday', y='cnt', data=df, estimator=sum, palette='muted')
plt.title("Penggunaan Sepeda: Weekday vs Weekend")
plt.show()

plt.figure(figsize=(8, 5))
sns.barplot(x='holiday', y='cnt', data=df, estimator=sum, palette='Blues')
plt.title("Penggunaan Sepeda: Holiday vs Non-Holiday")
plt.show()
# Out:
# <ipython-input-16-975f0a3582dd>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='workingday', y='cnt', data=df, estimator=sum, palette='muted')
# <ipython-input-16-975f0a3582dd>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='holiday', y='cnt', data=df, estimator=sum, palette='Blues')

# %% [markdown]
# **Insight:**
# - Musim dan cuaca mempengaruhi penggunaan sepeda secara spesifik.
# - Weekday(hari kerja) memiliki penggunaan sepeda lebih tinggi dibandingkan weekend(hari libur)

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
rfm_df = df.groupby("workingday").agg({"cnt": ['mean', 'sum']})
rfm_df.columns = ['Rata-rata Penggunaan', 'Total Penggunaan']
display(rfm_df)
# Out:
#             Rata-rata Penggunaan  Total Penggunaan
# workingday
# Weekday              4584.820000           2292410
# Weekend              4330.168831           1000269

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1
# Musim Fall memiliki penggunaan sepeda paling tinggi dan cuaca yang cerah berkontribusi/semakin meningkatkan peningkatan penggunaan sepeda.
# - Conclusion pertanyaan 2
# Penggunaan sepeda lebih banyak terjadi pada hari kerja (weekday) dibandingkan akhir pekan/hari libur.
