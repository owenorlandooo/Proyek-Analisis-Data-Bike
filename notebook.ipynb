# %% [markdown]
# # Proyek Analisis Data: [Bike-sharing-dataset]
# - **Nama:** [Owen Orlando]
# - **Email:** [m197b4ky3465@bangkit.academy]
# - **ID Dicoding:** [owen_orlando_m197b4ky3465_sZVQ]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apakah penggunaan sepeda ditentukan oleh musim dan kondisi cuaca?
# - Apakah terdapat perbedaan saat penggunaan sepeda antara weekday (hari kerja) dan weekend (hari libur)?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv('sample_data/day.csv')
print("Preview Data:")
display(df.head())
# Out:
# Preview Data:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:**
# - Data terdiri dari 731 baris dengan 16 kolom
# - Terdapat kolom season, weathersit, holiday, dan working day yang merupakan data bentuk kategori

# %% [markdown]
# ### Assessing Data

# %%
print("\nInformasi Dataset:")
df.info()

print("\nStatistik Deskriptif Dataset:")
display(df.describe())
print("\nCek Missing Values:")
print(df.isnull().sum())
print("\nCek Duplikasi:")
print(df.duplicated().sum())

print("\nUnique Values untuk Kolom Kategori:")
print("Season:", df['season'].unique())
print("Weathersit:", df['weathersit'].unique())
print("Holiday:", df['holiday'].unique())
print("Workingday:", df['workingday'].unique())
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
#
# Statistik Deskriptif Dataset:
# ...

# %% [markdown]
# **Insight:**
# - Tidak ditemukan adanya missing values ataupun duplikasi dalam dataset
# - Kolom kategori memiliki nilai yang sesuai dengan deskripsi seperti season (1(spring), 2(summer), 3(fall), dan 4 winter) dan weathersit.

# %% [markdown]
# ### Cleaning Data

# %%
df['season'] = df['season'].map({1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})
df['weathersit'] = df['weathersit'].map({
    1: 'Clear',
    2: 'Mist',
    3: 'Light Rain/Snow',
    4: 'Heavy Rain/Snow'
})
df['workingday'] = df['workingday'].map({1: 'Weekday', 0: 'Weekend'})
df['holiday'] = df['holiday'].map({1: 'Holiday', 0: 'Not Holiday'})

print("Preview Data Setelah Pembersihan:")
display(df.head())
# Out:
# Preview Data Setelah Pembersihan:
#    instant      dteday  season  yr  mnth      holiday  weekday workingday  \
# 0        1  2011-01-01  Spring   0     1  Not Holiday        6    Weekend
# 1        2  2011-01-02  Spring   0     1  Not Holiday        0    Weekend
# 2        3  2011-01-03  Spring   0     1  Not Holiday        1    Weekday
# 3        4  2011-01-04  Spring   0     1  Not Holiday        2    Weekday
# 4        5  2011-01-05  Spring   0     1  Not Holiday        3    Weekday
#
#   weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0       Mist  0.344167  0.363625  0.805833   0.160446     331         654
# 1       Mist  0.363478  0.353739  0.696087   0.248539     131         670
# 2      Clear  0.196364  0.189405  0.437273   0.248309     120        1229
# 3      Clear  0.200000  0.212122  0.590435   0.160296     108        1454
# 4      Clear  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# ...

# %% [markdown]
# **Insight:**
# - Kolom kategori sudah dikonversi menjadi deskripsi sehingga lebih mudah untuk dipahami
# - Data sudah siap untuk ke tahap exploratory data analysis (EDA)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### EDA Univariate

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['cnt'], bins=30, kde=True, color="skyblue")
plt.title("Distribusi Jumlah Penyewaan Sepeda")
plt.show()

# %% [markdown]
# **Insight:**
# - Distribusi cnt memiliki puncak 4000-5000

# %% [markdown]
# ### EDA Numerik

# %%
display(df.describe())
# Out:
#           instant          yr        mnth     weekday        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    0.500684    6.519836    2.997264    0.495385    0.474354
# std    211.165812    0.500342    3.451913    2.004787    0.183051    0.162961
# min      1.000000    0.000000    1.000000    0.000000    0.059130    0.079070
# 25%    183.500000    0.000000    4.000000    1.000000    0.337083    0.337842
# 50%    366.000000    1.000000    7.000000    3.000000    0.498333    0.486733
# 75%    548.500000    1.000000   10.000000    5.000000    0.655417    0.608602
# max    731.000000    1.000000   12.000000    6.000000    0.861667    0.840896
#
#               hum   windspeed       casual   registered          cnt
# count  731.000000  731.000000   731.000000   731.000000   731.000000
# mean     0.627894    0.190486   848.176471  3656.172367  4504.348837
# ...

# %%
numerik_cols = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']

plt.figure(figsize=(12, 8))
for i, col in enumerate(numerik_cols):
    plt.subplot(2, 3, i+1)
    sns.histplot(df[col], kde=True, color="skyblue")
    plt.title(f'Distribusi {col}')
plt.tight_layout()
plt.show()

# %%
numerik_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10, 6))
sns.heatmap(numerik_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap Korelasi Antar Variabel Numerik")
plt.show()

# %% [markdown]
# **Insight:**
# - Memudahkan dalam melihat ringkasan statistik (mean, median, min, max, dan standar deviation)
# - Menampilkan persebaran data numerik seperti temp, windspeed, dan cnt
# - Memudahkan dalam mengidentifikasi apabila ada outlier atau distribusi skewed
# - Pada bagian korelasi bertujuan untuk menampilkan hubungan antar variabel.

# %% [markdown]
# ### EDA Kategorikal

# %%
kategorikal_cols = ['season', 'weathersit', 'holiday', 'workingday']

plt.figure(figsize=(10, 8))
for i, col in enumerate(kategorikal_cols):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=col, data=df, palette='viridis')
    plt.title(f'Distribusi {col}')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-7642443bc8a6>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='viridis')
# <ipython-input-13-7642443bc8a6>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='viridis')
# <ipython-input-13-7642443bc8a6>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='viridis')
# <ipython-input-13-7642443bc8a6>:6: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(12, 8))

for i, col in enumerate(kategorikal_cols):
    plt.subplot(2, 2, i+1)
    sns.barplot(x=col, y='cnt', data=df, estimator='mean', palette='coolwarm')
    plt.title(f'Rata-rata Penyewaan Sepeda Berdasarkan {col}')
    plt.ylabel("Rata-rata Penyewaan")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-0ea781e29bd1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='cnt', data=df, estimator='mean', palette='coolwarm')
# <ipython-input-14-0ea781e29bd1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='cnt', data=df, estimator='mean', palette='coolwarm')
# <ipython-input-14-0ea781e29bd1>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y='cnt', data=df, estimator='mean', palette='coolwarm')
# <ipython-input-14-0ea781e29bd1>:5: FutureWarning:
#
# ...

# %% [markdown]
# **Insight:**
# - Grafik menunjukkan jumlah observasi per kategori (season, wethersit, holiday, dan workingday)
# - Memudahkan dalam melihat kategori mana yang memiliki penyewaan tertinggi (rata-rata)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='season', y='cnt', data=df, estimator='mean', palette='viridis')
plt.title("Rata-rata Penyewaan Sepeda Berdasarkan Musim")
plt.xlabel("Musim")
plt.ylabel("Rata-rata Penyewaan Sepeda")
plt.show()

plt.figure(figsize=(8, 5))
sns.barplot(x='weathersit', y='cnt', data=df, estimator='mean', palette='coolwarm')
plt.title("Rata-rata Penyewaan Sepeda Berdasarkan Kondisi Cuaca")
plt.xlabel("Kondisi Cuaca")
plt.ylabel("Rata-rata Penyewaan Sepeda")
plt.show()
# Out:
# <ipython-input-19-8c84fadbdaaf>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='season', y='cnt', data=df, estimator='mean', palette='viridis')
# <ipython-input-19-8c84fadbdaaf>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weathersit', y='cnt', data=df, estimator='mean', palette='coolwarm')

# %% [markdown]
# **Insight:**
# - Penggunaan sepeda paling tinggi pada saat musim fall dan paling rendah pada saat musim spring
# - Penggunaan/penyewaan sepeda paling tinggi saat kondisi cuaca Clear dan paling rendah saat kondisi cuaca light rain/snow

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Visualisasi Rata-rata Penyewaan: Weekday vs Weekend
plt.figure(figsize=(8, 5))
sns.barplot(x='workingday', y='cnt', data=df, estimator='mean', palette='muted')
plt.title("Rata-rata Penyewaan Sepeda: Weekday vs Weekend")
plt.xlabel("Tipe Hari")
plt.ylabel("Rata-rata Penyewaan Sepeda")
plt.show()

# Visualisasi Rata-rata Penyewaan: Holiday vs Non-Holiday
plt.figure(figsize=(8, 5))
sns.barplot(x='holiday', y='cnt', data=df, estimator='mean', palette='Blues')
plt.title("Rata-rata Penyewaan Sepeda: Holiday vs Non-Holiday")
plt.xlabel("Tipe Hari")
plt.ylabel("Rata-rata Penyewaan Sepeda")
plt.show()
# Out:
# <ipython-input-21-33556a226bf3>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='workingday', y='cnt', data=df, estimator='mean', palette='muted')
# <ipython-input-21-33556a226bf3>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='holiday', y='cnt', data=df, estimator='mean', palette='Blues')

# %% [markdown]
# **Insight:**
# - Weekday(hari kerja) dan Non holiday memiliki penggunaan sepeda lebih tinggi dibandingkan weekend(hari libur) Holiday dan Weekend

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
df['usage_group'] = pd.qcut(df['cnt'], q=3, labels=['Rendah', 'Sedang', 'Tinggi'])
plt.figure(figsize=(8, 5))
sns.countplot(x='usage_group', data=df, palette='muted')
plt.title("Distribusi Kelompok Penyewaan Sepeda Berdasarkan Frekuensi")
plt.xlabel("Kategori Penyewaan")
plt.show()

monthly_usage = df.groupby(['season', 'usage_group'])['cnt'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='season', y='cnt', hue='usage_group', data=monthly_usage, palette='coolwarm')
plt.title("Rata-rata Penyewaan Sepeda Berdasarkan Musim dan Kategori Penggunaan")
plt.xlabel("Musim")
plt.ylabel("Rata-rata Penyewaan")
plt.show()
# Out:
# <ipython-input-17-1bf8fa999cad>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='usage_group', data=df, palette='muted')
# <ipython-input-17-1bf8fa999cad>:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_usage = df.groupby(['season', 'usage_group'])['cnt'].mean().reset_index()

# %% [markdown]
# **Insight:**
# - Penggunaan sepeda paling banyak ada di Musim Fall
# - Penggunaan sepeda paling sedikit ada di Musim Winter

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1
# -Apakah penggunaan sepeda ditentukan oleh musim dan kondisi cuaca?
# -- Ya, penggunaan sepeda ditentukan oleh musim dan kondisi cuaca. Berdasarkan data yang sudah dianalisis dapat diketahui bahwa pada saat musim Fall jumlah penyewaan sepeda berada paling tinggi dibandingkan dengan musim-musim lain, dengan total rata-rata penggunaan mencapai 5000 penyewaan per hari. Juga dengan kondisi cuaca juga mempengaruhi tingkat penggunaan sepeda, yang mana cuaca cerah (Clear) berkontribusi secara signifikan terhadap peningkatan jumlah penyewaan.
#
# - Conclusion pertanyaan 2
# - Apakah terdapat perbedaan saat penggunaan sepeda antara weekday (hari kerja) dan weekend (hari libur)?
# -- Ya, terdapat perbedaan  saat penggunaan sepeda antara weekday dan weekend. Berdasarkan data yang telah dianalisis dapat disimpulkan bahwa weekday memiliki jumlah rata-rata penyewaan sepeda lebih tinggi dibandingkan weekend, yang menunjukkan bahwa sepeda lebih banyak digunakan.
